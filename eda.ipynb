# %%
import pandas as pd

# %%
df = pd.read_csv("esc50_lstm_curriculum_curriculum_val_history.csv")

# %%
df.head()
# Out:
#    batch_num  val_acc  val_loss  std_val_acc
# 0         49   0.0400  3.994873          NaN
# 1         99   0.0625  4.264214          NaN
# 2        149   0.0925  4.170377          NaN
# 3        199   0.0950  4.493012          NaN
# 4        249   0.1175  4.041415          NaN

# %%
# plot val_acc
df.plot(x="batch_num", y="val_acc", title="Validation Accuracy over Epochs")
# Out:
# <Axes: title={'center': 'Validation Accuracy over Epochs'}, xlabel='batch_num'>

# %%
# plot val loss
df.plot(x="batch_num", y="val_loss", title="Validation Loss over Epochs")
# Out:
# <Axes: title={'center': 'Validation Loss over Epochs'}, xlabel='batch_num'>
